# %% [markdown]
# ### Technical Report: Analysis of Global Educational Inequality
#
# #### Objective
# The objective of this analysis is to explore global educational inequality trends from 2010 to 2021, examining how disparities vary across countries and regions. By identifying key patterns and relationships, this report aims to shed light on the factors contributing to these inequalities and inform policy efforts to reduce them.
#
# #### Dataset Overview
# The dataset utilized in this analysis is titled *Inequality in Education Around the World*, encompassing historical data on educational inequality indicators from 2010 to 2021. The dataset includes 195 countries and features columns such as:
#
# - **ISO3**: Country code.
# - **Country**: Name of the country.
# - **Human Development Groups**: Categorization by development level (e.g., Low, Medium, High, Very High).
# - **UNDP Developing Regions**: Regional grouping (e.g., Sub-Saharan Africa (SSA), Latin America and the Caribbean (LAC)).
# - **HDI Rank (2021)**: Human Development Index rank for 2021.
# - **Inequality in Education (2010-2021)**: Yearly educational inequality scores.
#
# #### Exploratory Data Analysis (EDA)
# The dataset analysis began with an inspection of the data structure, types, and completeness. A heatmap visualized missing values, revealing incomplete data across several years for specific countries and columns.
#
# ##### Global Trends in Educational Inequality (2010-2021)
# A line plot was used to depict the global average of educational inequality over the 12-year period. This visualization showed that while some fluctuation exists, there is a general downward trend, indicating improvements in educational access and quality in many parts of the world. The confidence interval represented by the shaded region displayed variations in inequality scores.
#
# ##### Regional Disparities in Educational Inequality (2021)
# Two specific analyses were conducted for 2021:
# 1. **Box Plot by UNDP Regions**:
#    - **Findings**: Sub-Saharan Africa (SSA) and South Asia (SA) regions displayed higher median educational inequality. In contrast, regions like Europe and Central Asia (ECA) had lower medians, indicating better education equity.
#    - **Implications**: These findings highlight the need for focused educational interventions in lower-performing regions.
#
# 2. **Violin Plot by Human Development Groups**:
#    - **Findings**: Countries in the "Low" human development group exhibited significant variability and higher median educational inequality. "Very High" development groups consistently had lower inequality scores, emphasizing the link between socioeconomic development and access to quality education.
#    - **Implications**: Reducing educational disparities may require multi-faceted approaches that address broader social and economic inequalities.
#
# ##### Correlation Analysis: HDI Rank and Educational Inequality (2021)
# A scatter plot was used to analyze the relationship between the 2021 HDI rank and educational inequality:
# - **Observations**: Higher HDI-ranked countries (those with lower numerical values) generally had lower educational inequality. The scatter plot, with countries color-coded by region, illustrated that regions like SSA and SA clustered at higher inequality levels, while ECA and East Asia and the Pacific (EAP) tended to perform better.
# - **Conclusion**: This analysis confirms that educational inequality is closely linked to a country's overall human development, suggesting that policies improving economic and social development can also lead to more equitable educational outcomes.
#
# #### Insights and Key Observations
# 1. **Overall Improvement**: The global trend indicates progress, with many countries showing reductions in educational inequality over the past decade.
# 2. **Regional Disparities**: Sub-Saharan Africa and South Asia have the highest educational inequality, pointing to persistent challenges in access and quality. This underscores the importance of targeted educational investments and reforms.
# 3. **Impact of Development Level**: Countries classified under "Very High" human development consistently display lower educational inequality, suggesting that development and education are interlinked.
# 4. **HDI and Education**: The strong inverse relationship between HDI rank and educational inequality highlights the importance of integrated policy approaches that address both economic development and education.
#
#
# #### Conclusion
# The analysis provided a comprehensive overview of global educational inequality from 2010 to 2021, underscoring significant regional disparities and the role of human development. Addressing educational inequality requires holistic approaches that encompass not only educational policies but also broader socioeconomic development efforts.
#
#
# ### Reference
#
#  - https://www.kaggle.com/datasets/iamsouravbanerjee/inequality-in-education-around-the-world/data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

### setting the seaborn style for visualizations
sns.set(style="whitegrid")

### loading the dataset from the uploaded file
file_path = 'Inequality in Education.csv'
data = pd.read_csv(file_path)

### displaying the first few rows of the dataset to understand its structure
data.head()
# Out:
#   ISO3               Country Human Development Groups UNDP Developing Regions  \
# 0  AFG           Afghanistan                      Low                      SA
# 1  AGO                Angola                   Medium                     SSA
# 2  ALB               Albania                     High                     ECA
# 3  AND               Andorra                Very High                     NaN
# 4  ARE  United Arab Emirates                Very High                      AS
#
#    HDI Rank (2021)  Inequality in Education (2010)  \
# 0            180.0                       42.809000
# 1            148.0                             NaN
# 2             67.0                       11.900000
# 3             40.0                       15.160302
# 4             26.0                             NaN
#
#    Inequality in Education (2011)  Inequality in Education (2012)  \
# 0                       44.823380                       44.823380
# 1                             NaN                             NaN
# 2                       11.900000                       11.900000
# 3                       15.160302                       15.160302
# 4                             NaN                             NaN
#
#    Inequality in Education (2013)  Inequality in Education (2014)  \
# 0                       44.823380                       44.823380
# 1                             NaN                             NaN
# 2                       11.900000                       11.900000
# 3                       15.160302                        9.965681
# 4                             NaN                             NaN
#
#    Inequality in Education (2015)  Inequality in Education (2016)  \
# 0                       45.365170                       45.365170
# 1                       34.171440                       34.171440
# 2                       11.900000                       11.900000
# 3                       10.083815                       10.008154
# 4                             NaN                       18.241437
#
#    Inequality in Education (2017)  Inequality in Education (2018)  \
# 0                       45.365170                       45.365170
# 1                       34.171440                       34.171440
# 2                       12.333440                       12.333440
# 3                       10.008154                       10.008154
# 4                       14.475335                       12.634355
#
#    Inequality in Education (2019)  Inequality in Education (2020)  \
# 0                       45.365170                       45.365170
# 1                       34.171440                       34.171440
# 2                       12.333440                       12.333440
# 3                       10.008154                       10.008154
# 4                       12.634355                       12.634355
#
#    Inequality in Education (2021)
# 0                       45.365170
# 1                       34.171440
# 2                       12.333440
# 3                       10.008154
# 4                       12.634355

# %%
### inspecting the dataset to identify missing values and data types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ISO3                            195 non-null    object
#  1   Country                         195 non-null    object
#  2   Human Development Groups        191 non-null    object
#  3   UNDP Developing Regions         151 non-null    object
#  4   HDI Rank (2021)                 191 non-null    float64
#  5   Inequality in Education (2010)  137 non-null    float64
#  6   Inequality in Education (2011)  150 non-null    float64
#  7   Inequality in Education (2012)  157 non-null    float64
#  8   Inequality in Education (2013)  165 non-null    float64
#  9   Inequality in Education (2014)  168 non-null    float64
#  10  Inequality in Education (2015)  168 non-null    float64
#  11  Inequality in Education (2016)  168 non-null    float64
#  12  Inequality in Education (2017)  168 non-null    float64
#  13  Inequality in Education (2018)  172 non-null    float64
#  14  Inequality in Education (2019)  174 non-null    float64
#  15  Inequality in Education (2020)  176 non-null    float64
#  16  Inequality in Education (2021)  176 non-null    float64
# dtypes: float64(13), object(4)
# memory usage: 26.0+ KB

# %%
### checking basic statistics of the dataset
data.describe()
# Out:
#        HDI Rank (2021)  Inequality in Education (2010)  \
# count       191.000000                      137.000000
# mean         95.811518                       20.654419
# std          55.307333                       14.392552
# min           1.000000                        1.322970
# 25%          48.500000                        6.917102
# 50%          96.000000                       17.825000
# 75%         143.500000                       30.542861
# max         191.000000                       48.723000
#
#        Inequality in Education (2011)  Inequality in Education (2012)  \
# count                      150.000000                      157.000000
# mean                        19.991823                       19.473658
# std                         14.342499                       14.305732
# min                          1.385640                        1.390450
# 25%                          6.119250                        6.011760
# 50%                         17.312742                       16.421150
# 75%                         30.176057                       30.201410
# max                         48.723000                       48.723000
#
#        Inequality in Education (2013)  Inequality in Education (2014)  \
# count                      165.000000                      168.000000
# mean                        19.258472                       19.135457
# std                         14.470344                       14.350759
# min                          0.779397                        0.765510
# 25%                          5.605950                        6.127907
# 50%                         16.060770                       15.957630
# 75%                         30.542861                       30.564901
# max                         49.321290                       49.321290
#
#        Inequality in Education (2015)  Inequality in Education (2016)  \
# count                      168.000000                      168.000000
# mean                        19.133751                       18.853851
# std                         14.475000                       14.479261
# min                          0.757375                        0.724854
# 25%                          6.209205                        6.130745
# 50%                         15.344075                       14.461598
# 75%                         29.686837                       29.647365
# max                         49.321290                       49.321290
#
#        Inequality in Education (2017)  Inequality in Education (2018)  \
# count                      168.000000                      172.000000
# mean                        18.649140                       18.396401
# std                         14.558072                       14.546446
# min                          0.724854                        0.550110
# 25%                          5.591175                        5.854422
# 50%                         14.292875                       13.565415
# 75%                         29.647365                       29.326065
# max                         49.321290                       50.124110
#
#        Inequality in Education (2019)  Inequality in Education (2020)  \
# count                      174.000000                      176.000000
# mean                        18.212993                       18.006314
# std                         14.553003                       14.569313
# min                          0.550110                        0.550110
# 25%                          5.618515                        5.518733
# 50%                         13.263530                       12.843558
# 75%                         29.303075                       28.335352
# max                         50.124110                       50.124110
#
#        Inequality in Education (2021)
# count                      176.000000
# mean                        18.006314
# std                         14.569313
# min                          0.550110
# 25%                          5.518733
# 50%                         12.843558
# 75%                         28.335352
# max                         50.124110

# %% [markdown]
# The dataset contains 195 entries and 17 columns, with a mix of complete and missing data for various years of "Inequality in Education" and other attributes.

# %%
### visualizing missing data using a heatmap
plt.figure(figsize=(14, 8))
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
plt.title('Heatmap of Missing Values in the Dataset')
plt.show()

# %%
### reshaping the dataset for analysis
years = [str(year) for year in range(2010, 2022)]
data_long = data.melt(
    id_vars=["Country", "ISO3", "Human Development Groups", "UNDP Developing Regions", "HDI Rank (2021)"],
    value_vars=[f"Inequality in Education ({year})" for year in years],
    var_name="Year", value_name="Inequality in Education"
)

# %%
### converting 'Year' to a numerical format
data_long['Year'] = data_long['Year'].str.extract('(\d+)').astype(int)

### plotting global average trend of educational inequality over time
plt.figure(figsize=(12, 6))
sns.lineplot(data=data_long, x='Year', y='Inequality in Education', estimator='mean', ci='sd')
plt.title('Global Average Educational Inequality Trend (2010-2021)')
plt.ylabel('Inequality in Education (Mean)')
plt.xlabel('Year')
plt.show()
# Out:
# <ipython-input-8-df51336f2f70>:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(data=data_long, x='Year', y='Inequality in Education', estimator='mean', ci='sd')

# %% [markdown]
# The line plot displays the global average trend of educational inequality from 2010 to 2021, along with a confidence interval for the standard deviation. This visualization highlights general patterns and changes over time, indicating whether inequality in education has been increasing, decreasing, or remaining stable. Overall, we can observe a slight decline in Inequality in Education during this period.

# %%
### visualizing educational inequality by UNDP Developing Regions for 2021
plt.figure(figsize=(14, 8))
sns.boxplot(data=data_long[data_long['Year'] == 2021],
            x='UNDP Developing Regions', y='Inequality in Education')
plt.title('Educational Inequality by UNDP Developing Regions in 2021')
plt.ylabel('Inequality in Education (2021)')
plt.xlabel('Region')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# (From the box plot) Educational Inequality by UNDP Developing Regions:
#
#  - Regions such as Sub-Saharan Africa (SSA) and South Asia (SA) show higher median levels of educational inequality.
#  - Europe and Central Asia (ECA) and East Asia and the Pacific (EAP) tend to have lower median inequality, indicating better access and quality of education.

# %%
### comparing inequality based on human development groups in 2021
plt.figure(figsize=(14, 8))
sns.violinplot(data=data_long[data_long['Year'] == 2021],
               x='Human Development Groups', y='Inequality in Education')
plt.title('Educational Inequality by Human Development Groups in 2021')
plt.ylabel('Inequality in Education (2021)')
plt.xlabel('Human Development Group')
plt.show()

# %% [markdown]
# (From the violin plot) Educational Inequality by Human Development Groups:
#
#  - Countries in the "Low" human development group display higher variability and higher average educational inequality.
#  - "Very High" development groups show significantly lower levels of educational inequality, highlighting the disparities between groups with different developmental levels.

# %%
### scatter plot to show the correlation between HDI Rank and educational inequality in 2021
plt.figure(figsize=(12, 8))
sns.scatterplot(data=data, x='HDI Rank (2021)', y='Inequality in Education (2021)',
                hue='UNDP Developing Regions', palette='Set2', alpha=0.7)
plt.title('Correlation Between HDI Rank and Educational Inequality (2021)')
plt.xlabel('HDI Rank (2021)')
plt.ylabel('Inequality in Education (2021)')
plt.gca().invert_xaxis()  ### inverting the x-axis for a more intuitive view (higher HDI rank = lower development)
plt.legend(title='Region', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# The scatter plot illustrates the relationship between the Human Development Index (HDI) rank and educational inequality in 2021.
#
#  - General Observation: Countries with higher HDI ranks (lower numerical value) tend to have lower educational inequality, indicating that more developed countries usually have better educational access and quality.
#  - Regional Insights: The markers, colored by region, show distinct clusters, with regions like Sub-Saharan Africa and South Asia displaying higher educational inequality for lower HDI ranks, while Europe and Central Asia generally have lower inequality for higher HDI ranks.
